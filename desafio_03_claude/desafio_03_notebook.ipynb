# %%
import pandas as pd
import numpy as np
import json

# %%
with open('churn_nordeste_raw.json', 'r') as f:
    json_bruto = json.load(f)

# %%
json_bruto
# Out:
# {'regional': 'Nordeste',
#  'data_extracao': '2026-02-13',
#  'clientes': [{'id_cliente': 'NE-10201',
#    'info_pessoal': {'genero': 'Masculino',
#     'idoso': 0,
#     'parceiro': 'Sim',
#     'dependentes': 'Nao'},
#    'conta': {'meses_contrato': 12,
#     'tipo_contrato': 'Mensal',
#     'pagamento': 'Boleto bancÃ¡rio',
#     'cobranca_mensal': '89,90',
#     'cobranca_total': '1078,80'},
#    'servicos': {'telefone': 'Sim',
#     'internet': 'Fibra Ã³tica',
#     'seguranca_online': 'Nao',
#     'backup_online': 'Nao'},
#    'churn': 'Sim'},
#   {'id_cliente': 'NE-10201',
#    'info_pessoal': {'genero': 'Masculino',
#     'idoso': 0,
#     'parceiro': 'Sim',
#     'dependentes': 'Nao'},
#    'conta': {'meses_contrato': 12,
#     'tipo_contrato': 'Mensal',
#     'pagamento': 'Boleto bancÃ¡rio',
#     'cobranca_mensal': '89,90',
#     'cobranca_total': '1078,80'},
#    'servicos': {'telefone': 'Sim',
#     'internet': 'Fibra Ã³tica',
#     'seguranca_online': 'Nao',
#     'backup_online': 'Nao'},
#    'churn': 'Sim'},
#   {'id_cliente': 'NE-10202',
#    'info_pessoal': {'genero': 'Feminino',
#     'idoso': 1,
#     'parceiro': 'Nao',
#     'dependentes': 'Nao'},
#    'conta': {'meses_contrato': 48,
#     'tipo_contrato': 'Dois anos',
#     'pagamento': 'CartÃ£o de crÃ©dito',
#     'cobranca_mensal': '45,50',
#     'cobranca_total': '2184,00'},
#    'servicos': {'telefone': 'Sim',
#     'internet': 'DSL',
#     'seguranca_online': 'Sim',
#     'backup_online': 'Sim'},
#    'churn': 'Nao'},
#   {'id_cliente': 'NE-10202',
#    'info_pessoal': {'genero': 'Feminino',
#     'idoso': 1,
#     'parceiro': 'Nao',
#     'dependentes': 'Nao'},
#    'conta': {'meses_contrato': 6,
#     'tipo_contrato': 'Mensal',
#     'pagamento': 'DÃ©bito automÃ¡tico',
#     'cobranca_mensal': '72,00',
#     'cobranca_total': '432,00'},
#    'servicos': {'telefone': 'Sim',
#     'internet': 'Fibra Ã³tica',
#     'seguranca_online': 'Nao',
#     'backup_online': 'Nao'},
#    'churn': 'Sim'},
#   {'id_cliente': 'NE-10203',
#    'info_pessoal': {'genero': 'Masculino',
#     'idoso': 0,
#     'parceiro': 'Sim',
#     'dependentes': 'Sim'},
#    'conta': {'meses_contrato': 2,
#     'tipo_contrato': 'Mensal',
#     'pagamento': 'DÃ©bito automÃ¡tico',
#     'cobranca_mensal': '120,00',
#     'cobranca_total': '240,00'},
#    'servicos': {'telefone': 'Nao',
#     'internet': 'Fibra Ã³tica',
#     'seguranca_online': 'Sim',
#     'backup_online': 'Nao'},
#    'churn': ' '},
#   {'id_cliente': 'NE-10204',
#    'info_pessoal': {'genero': '',
#     'idoso': 0,
#     'parceiro': 'Sim',
#     'dependentes': 'Nao'},
#    'conta': {'meses_contrato': 24,
#     'tipo_contrato': 'Um ano',
#     'pagamento': 'Boleto bancÃ¡rio',
#     'cobranca_mensal': '75,30',
#     'cobranca_total': '1807,20'},
#    'servicos': {'telefone': 'Sim',
#     'internet': 'Fibra Ã³tica',
#     'seguranca_online': 'Nao',
#     'backup_online': 'Sim'},
#    'churn': 'Nao'},
#   {'id_cliente': 'NE-10205',
#    'info_pessoal': {'genero': 'Feminino',
#     'idoso': 1,
#     'parceiro': 'Nao',
#     'dependentes': 'Nao'},
#    'conta': {'meses_contrato': 1,
#     'tipo_contrato': 'Mensal',
#     'pagamento': 'Boleto bancÃ¡rio',
#     'cobranca_mensal': '99,99',
#     'cobranca_total': '99,99'},
#    'servicos': {'telefone': 'Sim',
#     'internet': 'Fibra Ã³tica',
#     'seguranca_online': 'Nao',
#     'backup_online': 'Nao'},
#    'churn': 'Sim'},
#   {'id_cliente': 'NE-10206',
#    'info_pessoal': {'genero': 'Masculino',
#     'idoso': 0,
#     'parceiro': 'Nao',
#     'dependentes': 'Nao'},
#    'conta': {'meses_contrato': 36,
#     'tipo_contrato': 'Dois anos',
#     'pagamento': 'CartÃ£o de crÃ©dito',
#     'cobranca_mensal': '55,00',
#     'cobranca_total': '1980,00'},
#    'servicos': {'telefone': 'Sim',
#     'internet': 'DSL',
#     'seguranca_online': 'Sim',
#     'backup_online': 'Sim'},
#    'churn': 'Nao'},
#   {'id_cliente': 'NE-10207',
#    'info_pessoal': {'genero': '',
#     'idoso': 0,
#     'parceiro': 'Sim',
#     'dependentes': 'Sim'},
#    'conta': {'meses_contrato': 8,
#     'tipo_contrato': 'Mensal',
#     'pagamento': 'Boleto bancÃ¡rio',
#     'cobranca_mensal': '110,50',
#     'cobranca_total': '884,00'},
#    'servicos': {'telefone': 'Sim',
#     'internet': 'Fibra Ã³tica',
#     'seguranca_online': 'Nao',
#     'backup_online': 'Nao'},
#    'churn': 'Nao'},
#   {'id_cliente': 'NE-10208',
#    'info_pessoal': {'genero': 'Feminino',
#     'idoso': 1,
#     'parceiro': 'Nao',
#     'dependentes': 'Nao'},
#    'conta': {'meses_contrato': 15,
#     'tipo_contrato': 'Um ano',
#     'pagamento': 'DÃ©bito automÃ¡tico',
#     'cobranca_mensal': '65,00',
#     'cobranca_total': '975,00'},
#    'servicos': {'telefone': 'Nao',
#     'internet': 'DSL',
#     'seguranca_online': 'Sim',
#     'backup_online': 'Sim'},
#    'churn': ''}]}

# %%
dados_normalizados = pd.json_normalize(json_bruto, record_path='clientes', meta=['regional', 'data_extracao'], sep='_')

# %%
dados_normalizados
# Out:
#   id_cliente churn info_pessoal_genero  info_pessoal_idoso  \
# 0   NE-10201   Sim           Masculino                   0
# 1   NE-10201   Sim           Masculino                   0
# 2   NE-10202   Nao            Feminino                   1
# 3   NE-10202   Sim            Feminino                   1
# 4   NE-10203                 Masculino                   0
# 5   NE-10204   Nao                                       0
# 6   NE-10205   Sim            Feminino                   1
# 7   NE-10206   Nao           Masculino                   0
# 8   NE-10207   Nao                                       0
# 9   NE-10208                  Feminino                   1
#
#   info_pessoal_parceiro info_pessoal_dependentes  conta_meses_contrato  \
# 0                   Sim                      Nao                    12
# 1                   Sim                      Nao                    12
# 2                   Nao                      Nao                    48
# 3                   Nao                      Nao                     6
# 4                   Sim                      Sim                     2
# 5                   Sim                      Nao                    24
# 6                   Nao                      Nao                     1
# 7                   Nao                      Nao                    36
# 8                   Sim                      Sim                     8
# 9                   Nao                      Nao                    15
#
#   conta_tipo_contrato      conta_pagamento conta_cobranca_mensal  \
# 0              Mensal     Boleto bancÃ¡rio                 89,90
# 1              Mensal     Boleto bancÃ¡rio                 89,90
# 2           Dois anos  CartÃ£o de crÃ©dito                 45,50
# 3              Mensal  DÃ©bito automÃ¡tico                 72,00
# 4              Mensal  DÃ©bito automÃ¡tico                120,00
# 5              Um ano     Boleto bancÃ¡rio                 75,30
# 6              Mensal     Boleto bancÃ¡rio                 99,99
# 7           Dois anos  CartÃ£o de crÃ©dito                 55,00
# 8              Mensal     Boleto bancÃ¡rio                110,50
# 9              Um ano  DÃ©bito automÃ¡tico                 65,00
#
#   conta_cobranca_total servicos_telefone servicos_internet  \
# 0              1078,80               Sim      Fibra Ã³tica
# 1              1078,80               Sim      Fibra Ã³tica
# 2              2184,00               Sim               DSL
# 3               432,00               Sim      Fibra Ã³tica
# 4               240,00               Nao      Fibra Ã³tica
# 5              1807,20               Sim      Fibra Ã³tica
# 6                99,99               Sim      Fibra Ã³tica
# 7              1980,00               Sim               DSL
# 8               884,00               Sim      Fibra Ã³tica
# 9               975,00               Nao               DSL
#
#   servicos_seguranca_online servicos_backup_online  regional data_extracao
# 0                       Nao                    Nao  Nordeste    2026-02-13
# 1                       Nao                    Nao  Nordeste    2026-02-13
# 2                       Sim                    Sim  Nordeste    2026-02-13
# 3                       Nao                    Nao  Nordeste    2026-02-13
# 4                       Sim                    Nao  Nordeste    2026-02-13
# 5                       Nao                    Sim  Nordeste    2026-02-13
# 6                       Nao                    Nao  Nordeste    2026-02-13
# 7                       Sim                    Sim  Nordeste    2026-02-13
# 8                       Nao                    Nao  Nordeste    2026-02-13
# 9                       Sim                    Sim  Nordeste    2026-02-13

# %%
dados_normalizados.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id_cliente                 10 non-null     str
#  1   churn                      10 non-null     str
#  2   info_pessoal_genero        10 non-null     str
#  3   info_pessoal_idoso         10 non-null     int64
#  4   info_pessoal_parceiro      10 non-null     str
#  5   info_pessoal_dependentes   10 non-null     str
#  6   conta_meses_contrato       10 non-null     int64
#  7   conta_tipo_contrato        10 non-null     str
#  8   conta_pagamento            10 non-null     str
#  9   conta_cobranca_mensal      10 non-null     str
#  10  conta_cobranca_total       10 non-null     str
#  11  servicos_telefone          10 non-null     str
#  12  servicos_internet          10 non-null     str
#  13  servicos_seguranca_online  10 non-null     str
#  14  servicos_backup_online     10 non-null     str
#  15  regional                   10 non-null     str
#  16  data_extracao              10 non-null     str
# dtypes: int64(2), str(15)
# memory usage: 1.5 KB

# %%
dados_normalizados[['conta_cobranca_mensal', 'conta_cobranca_total']] = dados_normalizados[['conta_cobranca_mensal', 'conta_cobranca_total']].replace(',', '.', regex=True)

# %%
dados_normalizados['conta_cobranca_mensal'] = pd.to_numeric(dados_normalizados['conta_cobranca_mensal'])
dados_normalizados['conta_cobranca_total'] = pd.to_numeric(dados_normalizados['conta_cobranca_total'])

# %%
dados_normalizados
# Out:
#   id_cliente churn info_pessoal_genero  info_pessoal_idoso  \
# 0   NE-10201   Sim           Masculino                   0
# 1   NE-10201   Sim           Masculino                   0
# 2   NE-10202   Nao            Feminino                   1
# 3   NE-10202   Sim            Feminino                   1
# 4   NE-10203                 Masculino                   0
# 5   NE-10204   Nao                                       0
# 6   NE-10205   Sim            Feminino                   1
# 7   NE-10206   Nao           Masculino                   0
# 8   NE-10207   Nao                                       0
# 9   NE-10208                  Feminino                   1
#
#   info_pessoal_parceiro info_pessoal_dependentes  conta_meses_contrato  \
# 0                   Sim                      Nao                    12
# 1                   Sim                      Nao                    12
# 2                   Nao                      Nao                    48
# 3                   Nao                      Nao                     6
# 4                   Sim                      Sim                     2
# 5                   Sim                      Nao                    24
# 6                   Nao                      Nao                     1
# 7                   Nao                      Nao                    36
# 8                   Sim                      Sim                     8
# 9                   Nao                      Nao                    15
#
#   conta_tipo_contrato      conta_pagamento  conta_cobranca_mensal  \
# 0              Mensal     Boleto bancÃ¡rio                  89.90
# 1              Mensal     Boleto bancÃ¡rio                  89.90
# 2           Dois anos  CartÃ£o de crÃ©dito                  45.50
# 3              Mensal  DÃ©bito automÃ¡tico                  72.00
# 4              Mensal  DÃ©bito automÃ¡tico                 120.00
# 5              Um ano     Boleto bancÃ¡rio                  75.30
# 6              Mensal     Boleto bancÃ¡rio                  99.99
# 7           Dois anos  CartÃ£o de crÃ©dito                  55.00
# 8              Mensal     Boleto bancÃ¡rio                 110.50
# 9              Um ano  DÃ©bito automÃ¡tico                  65.00
#
#    conta_cobranca_total servicos_telefone servicos_internet  \
# 0               1078.80               Sim      Fibra Ã³tica
# 1               1078.80               Sim      Fibra Ã³tica
# 2               2184.00               Sim               DSL
# 3                432.00               Sim      Fibra Ã³tica
# 4                240.00               Nao      Fibra Ã³tica
# 5               1807.20               Sim      Fibra Ã³tica
# 6                 99.99               Sim      Fibra Ã³tica
# 7               1980.00               Sim               DSL
# 8                884.00               Sim      Fibra Ã³tica
# 9                975.00               Nao               DSL
#
#   servicos_seguranca_online servicos_backup_online  regional data_extracao
# 0                       Nao                    Nao  Nordeste    2026-02-13
# 1                       Nao                    Nao  Nordeste    2026-02-13
# 2                       Sim                    Sim  Nordeste    2026-02-13
# 3                       Nao                    Nao  Nordeste    2026-02-13
# 4                       Sim                    Nao  Nordeste    2026-02-13
# 5                       Nao                    Sim  Nordeste    2026-02-13
# 6                       Nao                    Nao  Nordeste    2026-02-13
# 7                       Sim                    Sim  Nordeste    2026-02-13
# 8                       Nao                    Nao  Nordeste    2026-02-13
# 9                       Sim                    Sim  Nordeste    2026-02-13

# %%
dados_normalizados.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id_cliente                 10 non-null     str
#  1   churn                      10 non-null     str
#  2   info_pessoal_genero        10 non-null     str
#  3   info_pessoal_idoso         10 non-null     int64
#  4   info_pessoal_parceiro      10 non-null     str
#  5   info_pessoal_dependentes   10 non-null     str
#  6   conta_meses_contrato       10 non-null     int64
#  7   conta_tipo_contrato        10 non-null     str
#  8   conta_pagamento            10 non-null     str
#  9   conta_cobranca_mensal      10 non-null     float64
#  10  conta_cobranca_total       10 non-null     float64
#  11  servicos_telefone          10 non-null     str
#  12  servicos_internet          10 non-null     str
#  13  servicos_seguranca_online  10 non-null     str
#  14  servicos_backup_online     10 non-null     str
#  15  regional                   10 non-null     str
#  16  data_extracao              10 non-null     str
# dtypes: float64(2), int64(2), str(13)
# memory usage: 1.5 KB

# %%
dados_normalizados['data_extracao'] = pd.to_datetime(dados_normalizados['data_extracao'], format='%Y-%m-%d')

# %%
dados_normalizados
# Out:
#   id_cliente churn info_pessoal_genero  info_pessoal_idoso  \
# 0   NE-10201   Sim           Masculino                   0
# 1   NE-10201   Sim           Masculino                   0
# 2   NE-10202   Nao            Feminino                   1
# 3   NE-10202   Sim            Feminino                   1
# 4   NE-10203                 Masculino                   0
# 5   NE-10204   Nao                                       0
# 6   NE-10205   Sim            Feminino                   1
# 7   NE-10206   Nao           Masculino                   0
# 8   NE-10207   Nao                                       0
# 9   NE-10208                  Feminino                   1
#
#   info_pessoal_parceiro info_pessoal_dependentes  conta_meses_contrato  \
# 0                   Sim                      Nao                    12
# 1                   Sim                      Nao                    12
# 2                   Nao                      Nao                    48
# 3                   Nao                      Nao                     6
# 4                   Sim                      Sim                     2
# 5                   Sim                      Nao                    24
# 6                   Nao                      Nao                     1
# 7                   Nao                      Nao                    36
# 8                   Sim                      Sim                     8
# 9                   Nao                      Nao                    15
#
#   conta_tipo_contrato      conta_pagamento  conta_cobranca_mensal  \
# 0              Mensal     Boleto bancÃ¡rio                  89.90
# 1              Mensal     Boleto bancÃ¡rio                  89.90
# 2           Dois anos  CartÃ£o de crÃ©dito                  45.50
# 3              Mensal  DÃ©bito automÃ¡tico                  72.00
# 4              Mensal  DÃ©bito automÃ¡tico                 120.00
# 5              Um ano     Boleto bancÃ¡rio                  75.30
# 6              Mensal     Boleto bancÃ¡rio                  99.99
# 7           Dois anos  CartÃ£o de crÃ©dito                  55.00
# 8              Mensal     Boleto bancÃ¡rio                 110.50
# 9              Um ano  DÃ©bito automÃ¡tico                  65.00
#
#    conta_cobranca_total servicos_telefone servicos_internet  \
# 0               1078.80               Sim      Fibra Ã³tica
# 1               1078.80               Sim      Fibra Ã³tica
# 2               2184.00               Sim               DSL
# 3                432.00               Sim      Fibra Ã³tica
# 4                240.00               Nao      Fibra Ã³tica
# 5               1807.20               Sim      Fibra Ã³tica
# 6                 99.99               Sim      Fibra Ã³tica
# 7               1980.00               Sim               DSL
# 8                884.00               Sim      Fibra Ã³tica
# 9                975.00               Nao               DSL
#
#   servicos_seguranca_online servicos_backup_online  regional data_extracao
# 0                       Nao                    Nao  Nordeste    2026-02-13
# 1                       Nao                    Nao  Nordeste    2026-02-13
# 2                       Sim                    Sim  Nordeste    2026-02-13
# 3                       Nao                    Nao  Nordeste    2026-02-13
# 4                       Sim                    Nao  Nordeste    2026-02-13
# 5                       Nao                    Sim  Nordeste    2026-02-13
# 6                       Nao                    Nao  Nordeste    2026-02-13
# 7                       Sim                    Sim  Nordeste    2026-02-13
# 8                       Nao                    Nao  Nordeste    2026-02-13
# 9                       Sim                    Sim  Nordeste    2026-02-13

# %%
dados_normalizados.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id_cliente                 10 non-null     str
#  1   churn                      10 non-null     str
#  2   info_pessoal_genero        10 non-null     str
#  3   info_pessoal_idoso         10 non-null     int64
#  4   info_pessoal_parceiro      10 non-null     str
#  5   info_pessoal_dependentes   10 non-null     str
#  6   conta_meses_contrato       10 non-null     int64
#  7   conta_tipo_contrato        10 non-null     str
#  8   conta_pagamento            10 non-null     str
#  9   conta_cobranca_mensal      10 non-null     float64
#  10  conta_cobranca_total       10 non-null     float64
#  11  servicos_telefone          10 non-null     str
#  12  servicos_internet          10 non-null     str
#  13  servicos_seguranca_online  10 non-null     str
#  14  servicos_backup_online     10 non-null     str
#  15  regional                   10 non-null     str
#  16  data_extracao              10 non-null     datetime64[us]
# dtypes: datetime64[us](1), float64(2), int64(2), str(12)
# memory usage: 1.5 KB

# %%
dados_normalizados
# Out:
#   id_cliente churn info_pessoal_genero  info_pessoal_idoso  \
# 0   NE-10201   Sim           Masculino                   0
# 1   NE-10201   Sim           Masculino                   0
# 2   NE-10202   Nao            Feminino                   1
# 3   NE-10202   Sim            Feminino                   1
# 4   NE-10203                 Masculino                   0
# 5   NE-10204   Nao                                       0
# 6   NE-10205   Sim            Feminino                   1
# 7   NE-10206   Nao           Masculino                   0
# 8   NE-10207   Nao                                       0
# 9   NE-10208                  Feminino                   1
#
#   info_pessoal_parceiro info_pessoal_dependentes  conta_meses_contrato  \
# 0                   Sim                      Nao                    12
# 1                   Sim                      Nao                    12
# 2                   Nao                      Nao                    48
# 3                   Nao                      Nao                     6
# 4                   Sim                      Sim                     2
# 5                   Sim                      Nao                    24
# 6                   Nao                      Nao                     1
# 7                   Nao                      Nao                    36
# 8                   Sim                      Sim                     8
# 9                   Nao                      Nao                    15
#
#   conta_tipo_contrato      conta_pagamento  conta_cobranca_mensal  \
# 0              Mensal     Boleto bancÃ¡rio                  89.90
# 1              Mensal     Boleto bancÃ¡rio                  89.90
# 2           Dois anos  CartÃ£o de crÃ©dito                  45.50
# 3              Mensal  DÃ©bito automÃ¡tico                  72.00
# 4              Mensal  DÃ©bito automÃ¡tico                 120.00
# 5              Um ano     Boleto bancÃ¡rio                  75.30
# 6              Mensal     Boleto bancÃ¡rio                  99.99
# 7           Dois anos  CartÃ£o de crÃ©dito                  55.00
# 8              Mensal     Boleto bancÃ¡rio                 110.50
# 9              Um ano  DÃ©bito automÃ¡tico                  65.00
#
#    conta_cobranca_total servicos_telefone servicos_internet  \
# 0               1078.80               Sim      Fibra Ã³tica
# 1               1078.80               Sim      Fibra Ã³tica
# 2               2184.00               Sim               DSL
# 3                432.00               Sim      Fibra Ã³tica
# 4                240.00               Nao      Fibra Ã³tica
# 5               1807.20               Sim      Fibra Ã³tica
# 6                 99.99               Sim      Fibra Ã³tica
# 7               1980.00               Sim               DSL
# 8                884.00               Sim      Fibra Ã³tica
# 9                975.00               Nao               DSL
#
#   servicos_seguranca_online servicos_backup_online  regional data_extracao
# 0                       Nao                    Nao  Nordeste    2026-02-13
# 1                       Nao                    Nao  Nordeste    2026-02-13
# 2                       Sim                    Sim  Nordeste    2026-02-13
# 3                       Nao                    Nao  Nordeste    2026-02-13
# 4                       Sim                    Nao  Nordeste    2026-02-13
# 5                       Nao                    Sim  Nordeste    2026-02-13
# 6                       Nao                    Nao  Nordeste    2026-02-13
# 7                       Sim                    Sim  Nordeste    2026-02-13
# 8                       Nao                    Nao  Nordeste    2026-02-13
# 9                       Sim                    Sim  Nordeste    2026-02-13

# %%
colunas_strings = dados_normalizados.select_dtypes('str').columns

# %%
dados_normalizados[colunas_strings] = dados_normalizados[colunas_strings].apply(lambda x: x.str.strip())

# %%
dados_normalizados[colunas_strings] = dados_normalizados[colunas_strings].replace('', np.nan)

# %%
dados_normalizados
# Out:
#   id_cliente churn info_pessoal_genero  info_pessoal_idoso  \
# 0   NE-10201   Sim           Masculino                   0
# 1   NE-10201   Sim           Masculino                   0
# 2   NE-10202   Nao            Feminino                   1
# 3   NE-10202   Sim            Feminino                   1
# 4   NE-10203   NaN           Masculino                   0
# 5   NE-10204   Nao                 NaN                   0
# 6   NE-10205   Sim            Feminino                   1
# 7   NE-10206   Nao           Masculino                   0
# 8   NE-10207   Nao                 NaN                   0
# 9   NE-10208   NaN            Feminino                   1
#
#   info_pessoal_parceiro info_pessoal_dependentes  conta_meses_contrato  \
# 0                   Sim                      Nao                    12
# 1                   Sim                      Nao                    12
# 2                   Nao                      Nao                    48
# 3                   Nao                      Nao                     6
# 4                   Sim                      Sim                     2
# 5                   Sim                      Nao                    24
# 6                   Nao                      Nao                     1
# 7                   Nao                      Nao                    36
# 8                   Sim                      Sim                     8
# 9                   Nao                      Nao                    15
#
#   conta_tipo_contrato      conta_pagamento  conta_cobranca_mensal  \
# 0              Mensal     Boleto bancÃ¡rio                  89.90
# 1              Mensal     Boleto bancÃ¡rio                  89.90
# 2           Dois anos  CartÃ£o de crÃ©dito                  45.50
# 3              Mensal  DÃ©bito automÃ¡tico                  72.00
# 4              Mensal  DÃ©bito automÃ¡tico                 120.00
# 5              Um ano     Boleto bancÃ¡rio                  75.30
# 6              Mensal     Boleto bancÃ¡rio                  99.99
# 7           Dois anos  CartÃ£o de crÃ©dito                  55.00
# 8              Mensal     Boleto bancÃ¡rio                 110.50
# 9              Um ano  DÃ©bito automÃ¡tico                  65.00
#
#    conta_cobranca_total servicos_telefone servicos_internet  \
# 0               1078.80               Sim      Fibra Ã³tica
# 1               1078.80               Sim      Fibra Ã³tica
# 2               2184.00               Sim               DSL
# 3                432.00               Sim      Fibra Ã³tica
# 4                240.00               Nao      Fibra Ã³tica
# 5               1807.20               Sim      Fibra Ã³tica
# 6                 99.99               Sim      Fibra Ã³tica
# 7               1980.00               Sim               DSL
# 8                884.00               Sim      Fibra Ã³tica
# 9                975.00               Nao               DSL
#
#   servicos_seguranca_online servicos_backup_online  regional data_extracao
# 0                       Nao                    Nao  Nordeste    2026-02-13
# 1                       Nao                    Nao  Nordeste    2026-02-13
# 2                       Sim                    Sim  Nordeste    2026-02-13
# 3                       Nao                    Nao  Nordeste    2026-02-13
# 4                       Sim                    Nao  Nordeste    2026-02-13
# 5                       Nao                    Sim  Nordeste    2026-02-13
# 6                       Nao                    Nao  Nordeste    2026-02-13
# 7                       Sim                    Sim  Nordeste    2026-02-13
# 8                       Nao                    Nao  Nordeste    2026-02-13
# 9                       Sim                    Sim  Nordeste    2026-02-13

# %%
dados_normalizados.isna().sum()
# Out:
# id_cliente                   0
# churn                        2
# info_pessoal_genero          2
# info_pessoal_idoso           0
# info_pessoal_parceiro        0
# info_pessoal_dependentes     0
# conta_meses_contrato         0
# conta_tipo_contrato          0
# conta_pagamento              0
# conta_cobranca_mensal        0
# conta_cobranca_total         0
# servicos_telefone            0
# servicos_internet            0
# servicos_seguranca_online    0
# servicos_backup_online       0
# regional                     0
# data_extracao                0
# dtype: int64

# %%
dados_normalizados.shape[0]
# Out:
# 10

# %%
dados_sem_duplicadas = dados_normalizados.drop_duplicates()

# Como o método .drop_duplicate(), por default, compara todas as colunas do DataFrame, ele identifica linhas que tem o mesmo id_cliente,
# mas com outras células com valores diferentes. Dessa forma, essas linhas são consideradas como diferentes.

# %%
dados_sem_duplicadas.reset_index(drop=True, inplace=True)

# %%
linhas_removidas = dados_normalizados.shape[0] - dados_sem_duplicadas.shape[0]

# %%
print(f'A quantidade de linhas duplicadas reais removidas é: {linhas_removidas}')
# Out:
# A quantidade de linhas duplicadas reais removidas é: 1

# %%
dados_sem_duplicadas
# Out:
#   id_cliente churn info_pessoal_genero  info_pessoal_idoso  \
# 0   NE-10201   Sim           Masculino                   0
# 1   NE-10202   Nao            Feminino                   1
# 2   NE-10202   Sim            Feminino                   1
# 3   NE-10203   NaN           Masculino                   0
# 4   NE-10204   Nao                 NaN                   0
# 5   NE-10205   Sim            Feminino                   1
# 6   NE-10206   Nao           Masculino                   0
# 7   NE-10207   Nao                 NaN                   0
# 8   NE-10208   NaN            Feminino                   1
#
#   info_pessoal_parceiro info_pessoal_dependentes  conta_meses_contrato  \
# 0                   Sim                      Nao                    12
# 1                   Nao                      Nao                    48
# 2                   Nao                      Nao                     6
# 3                   Sim                      Sim                     2
# 4                   Sim                      Nao                    24
# 5                   Nao                      Nao                     1
# 6                   Nao                      Nao                    36
# 7                   Sim                      Sim                     8
# 8                   Nao                      Nao                    15
#
#   conta_tipo_contrato      conta_pagamento  conta_cobranca_mensal  \
# 0              Mensal     Boleto bancÃ¡rio                  89.90
# 1           Dois anos  CartÃ£o de crÃ©dito                  45.50
# 2              Mensal  DÃ©bito automÃ¡tico                  72.00
# 3              Mensal  DÃ©bito automÃ¡tico                 120.00
# 4              Um ano     Boleto bancÃ¡rio                  75.30
# 5              Mensal     Boleto bancÃ¡rio                  99.99
# 6           Dois anos  CartÃ£o de crÃ©dito                  55.00
# 7              Mensal     Boleto bancÃ¡rio                 110.50
# 8              Um ano  DÃ©bito automÃ¡tico                  65.00
#
#    conta_cobranca_total servicos_telefone servicos_internet  \
# 0               1078.80               Sim      Fibra Ã³tica
# 1               2184.00               Sim               DSL
# 2                432.00               Sim      Fibra Ã³tica
# 3                240.00               Nao      Fibra Ã³tica
# 4               1807.20               Sim      Fibra Ã³tica
# 5                 99.99               Sim      Fibra Ã³tica
# 6               1980.00               Sim               DSL
# 7                884.00               Sim      Fibra Ã³tica
# 8                975.00               Nao               DSL
#
#   servicos_seguranca_online servicos_backup_online  regional data_extracao
# 0                       Nao                    Nao  Nordeste    2026-02-13
# 1                       Sim                    Sim  Nordeste    2026-02-13
# 2                       Nao                    Nao  Nordeste    2026-02-13
# 3                       Sim                    Nao  Nordeste    2026-02-13
# 4                       Nao                    Sim  Nordeste    2026-02-13
# 5                       Nao                    Nao  Nordeste    2026-02-13
# 6                       Sim                    Sim  Nordeste    2026-02-13
# 7                       Nao                    Nao  Nordeste    2026-02-13
# 8                       Sim                    Sim  Nordeste    2026-02-13

# %%
moda = dados_sem_duplicadas['info_pessoal_genero'].mode()

# %%
moda[0]
# Out:
# 'Feminino'

# %%
colunas_valores_nulos = dados_sem_duplicadas.isna().sum()

# %%
dados_sem_duplicadas['info_pessoal_genero'] = dados_sem_duplicadas['info_pessoal_genero'].fillna(moda[0])

# %%
dados_sem_duplicadas
# Out:
#   id_cliente churn info_pessoal_genero  info_pessoal_idoso  \
# 0   NE-10201   Sim           Masculino                   0
# 1   NE-10202   Nao            Feminino                   1
# 2   NE-10202   Sim            Feminino                   1
# 3   NE-10203   NaN           Masculino                   0
# 4   NE-10204   Nao            Feminino                   0
# 5   NE-10205   Sim            Feminino                   1
# 6   NE-10206   Nao           Masculino                   0
# 7   NE-10207   Nao            Feminino                   0
# 8   NE-10208   NaN            Feminino                   1
#
#   info_pessoal_parceiro info_pessoal_dependentes  conta_meses_contrato  \
# 0                   Sim                      Nao                    12
# 1                   Nao                      Nao                    48
# 2                   Nao                      Nao                     6
# 3                   Sim                      Sim                     2
# 4                   Sim                      Nao                    24
# 5                   Nao                      Nao                     1
# 6                   Nao                      Nao                    36
# 7                   Sim                      Sim                     8
# 8                   Nao                      Nao                    15
#
#   conta_tipo_contrato      conta_pagamento  conta_cobranca_mensal  \
# 0              Mensal     Boleto bancÃ¡rio                  89.90
# 1           Dois anos  CartÃ£o de crÃ©dito                  45.50
# 2              Mensal  DÃ©bito automÃ¡tico                  72.00
# 3              Mensal  DÃ©bito automÃ¡tico                 120.00
# 4              Um ano     Boleto bancÃ¡rio                  75.30
# 5              Mensal     Boleto bancÃ¡rio                  99.99
# 6           Dois anos  CartÃ£o de crÃ©dito                  55.00
# 7              Mensal     Boleto bancÃ¡rio                 110.50
# 8              Um ano  DÃ©bito automÃ¡tico                  65.00
#
#    conta_cobranca_total servicos_telefone servicos_internet  \
# 0               1078.80               Sim      Fibra Ã³tica
# 1               2184.00               Sim               DSL
# 2                432.00               Sim      Fibra Ã³tica
# 3                240.00               Nao      Fibra Ã³tica
# 4               1807.20               Sim      Fibra Ã³tica
# 5                 99.99               Sim      Fibra Ã³tica
# 6               1980.00               Sim               DSL
# 7                884.00               Sim      Fibra Ã³tica
# 8                975.00               Nao               DSL
#
#   servicos_seguranca_online servicos_backup_online  regional data_extracao
# 0                       Nao                    Nao  Nordeste    2026-02-13
# 1                       Sim                    Sim  Nordeste    2026-02-13
# 2                       Nao                    Nao  Nordeste    2026-02-13
# 3                       Sim                    Nao  Nordeste    2026-02-13
# 4                       Nao                    Sim  Nordeste    2026-02-13
# 5                       Nao                    Nao  Nordeste    2026-02-13
# 6                       Sim                    Sim  Nordeste    2026-02-13
# 7                       Nao                    Nao  Nordeste    2026-02-13
# 8                       Sim                    Sim  Nordeste    2026-02-13

# %%
dados_sem_duplicadas.dropna(subset='churn', inplace=True)

# Como o objetivo principal da análise dos dados é verificar se houve ou não 'churn', as linhas em que os valores da célula dessa coluna sejam NaN
# não ajudaram em nada na referida análise. Motivo este dessas linhas poderem ser removidas do DataFrame sem nenhum prejuízo aparente.

# %%
dados_sem_duplicadas.reset_index(drop=True, inplace=True)

# %%
dados_sem_duplicadas
# Out:
#   id_cliente churn info_pessoal_genero  info_pessoal_idoso  \
# 0   NE-10201   Sim           Masculino                   0
# 1   NE-10202   Nao            Feminino                   1
# 2   NE-10202   Sim            Feminino                   1
# 3   NE-10204   Nao            Feminino                   0
# 4   NE-10205   Sim            Feminino                   1
# 5   NE-10206   Nao           Masculino                   0
# 6   NE-10207   Nao            Feminino                   0
#
#   info_pessoal_parceiro info_pessoal_dependentes  conta_meses_contrato  \
# 0                   Sim                      Nao                    12
# 1                   Nao                      Nao                    48
# 2                   Nao                      Nao                     6
# 3                   Sim                      Nao                    24
# 4                   Nao                      Nao                     1
# 5                   Nao                      Nao                    36
# 6                   Sim                      Sim                     8
#
#   conta_tipo_contrato      conta_pagamento  conta_cobranca_mensal  \
# 0              Mensal     Boleto bancÃ¡rio                  89.90
# 1           Dois anos  CartÃ£o de crÃ©dito                  45.50
# 2              Mensal  DÃ©bito automÃ¡tico                  72.00
# 3              Um ano     Boleto bancÃ¡rio                  75.30
# 4              Mensal     Boleto bancÃ¡rio                  99.99
# 5           Dois anos  CartÃ£o de crÃ©dito                  55.00
# 6              Mensal     Boleto bancÃ¡rio                 110.50
#
#    conta_cobranca_total servicos_telefone servicos_internet  \
# 0               1078.80               Sim      Fibra Ã³tica
# 1               2184.00               Sim               DSL
# 2                432.00               Sim      Fibra Ã³tica
# 3               1807.20               Sim      Fibra Ã³tica
# 4                 99.99               Sim      Fibra Ã³tica
# 5               1980.00               Sim               DSL
# 6                884.00               Sim      Fibra Ã³tica
#
#   servicos_seguranca_online servicos_backup_online  regional data_extracao
# 0                       Nao                    Nao  Nordeste    2026-02-13
# 1                       Sim                    Sim  Nordeste    2026-02-13
# 2                       Nao                    Nao  Nordeste    2026-02-13
# 3                       Nao                    Sim  Nordeste    2026-02-13
# 4                       Nao                    Nao  Nordeste    2026-02-13
# 5                       Sim                    Sim  Nordeste    2026-02-13
# 6                       Nao                    Nao  Nordeste    2026-02-13

# %%
print(f"""
RELATÓRIO FINAL
===============
- A quantidade de duplicatas reais removidas é: {linhas_removidas};
- A quantidade de nulos preenchidos pela moda da coluna 'info_pessoal_genero' é: {colunas_valores_nulos['info_pessoal_genero']};
- A quantidade de linhas dropadas por nulo no target é: {colunas_valores_nulos['churn']};
- O DataFrame final ficou com o seguinte shape:
    - Linhas: {dados_sem_duplicadas.shape[0]};
    - Colunas: {dados_sem_duplicadas.shape[1]}.
""")
# Out:
# RELATÓRIO FINAL
# ===============
# - A quantidade de duplicatas reais removidas é: 1;
# - A quantidade de nulos preenchidos pela moda da coluna 'info_pessoal_genero' é: 2;
# - A quantidade de linhas dropadas por nulo no target é: 2;
# - O DataFrame final ficou com o seguinte shape:
#     - Linhas: 7;
#     - Colunas: 17.

# %%
dados_sem_duplicadas.to_csv('churn_nordeste_clean.csv', sep=';', encoding='utf-8')
